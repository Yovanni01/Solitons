# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import Cod1Ex as cod

# %% [markdown]
# Problema 3.
# Inciso c.

# %%
def U_0(x):
    y=2*(1/np.cosh(x))**2;
    return y

def F(u):
    y=3*(u**2);
    return y

Dat1='Evolución en el tiempo del dato 1';
Dat2='Dato inicial 1';

cod.Dif_Fin(15,100,100,0.1,U_0,F,Dat1,Dat2)
# Out:
# Valor constante dt/dx=  0.0033333333333333335
# MovieWriter ffmpeg unavailable; using Pillow instead.

# %%
def U_0(x):
    y=8*(1/np.cosh(2*x+16))**2+2*(1/np.cosh(x+1))**2;
    return y

def F(u):
    y=3*(u**2);
    return y

Dat1='Evolución en el tiempo del dato 2';
Dat2='Dato inicial 2';

cod.Dif_Fin(15,100,100,0.1,U_0,F,Dat1,Dat2)
# Out:
# Valor constante dt/dx=  0.0033333333333333335
# MovieWriter ffmpeg unavailable; using Pillow instead.
